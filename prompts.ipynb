# %% [markdown]
# # AmazonQ

# %% [markdown]
# /docs Create a README for this CloudFormation template
# This would generate documentation for your current CloudFormation template, including:
#
# - Architecture overview of the VPC setup
# - Resource descriptions (VPC, subnets, NAT Gateway, EC2 instances)
# - Deployment instructions
# - Prerequisites and requirements
# - Parameter explanations
# - Security considerations
